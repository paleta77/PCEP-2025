# %%
# 1. tworzenie słownika

# %%
# 2. wypisanie elementu ze słownika ([])

# %%
# 3. wypisanie elementu ze słownika (get(klucz, domyślna_wartość))

# %% [markdown]
# Ćwiczenie 1.
# Stwórz słownik zawierający imiona i wiek. Wypisz wiek jednej dowolnej osoby w formacie "{imie} ma lat {wiek}" pobierając wiek ze słownika

# %%
# 4. wypisanie wszystkich kluczy (keys()) i sprawdzenie czy klucz istnieje

# %%
# 5. wypisanie wszystkich wartości (values())

# %%
# 6. dodawanie elementów do słownika ([])

# %%
# 7. usuwanie elementów ze słownika (del)

# %% [markdown]
# Ćwiczenie 2.
# Korzystając ze słownika z Ćwiczenia 1:
# Dodaj nową osobę, zaktualizuj wiek, usuń jedną pozycję.
